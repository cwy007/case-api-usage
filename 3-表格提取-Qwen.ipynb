# %%
import json
import os
import dashscope
from dashscope.api_entities.dashscope_response import Role
# 从环境变量中，获取 DASHSCOPE_API_KEY
api_key = os.environ.get('DASHSCOPE_API_KEY')
dashscope.api_key = api_key

# 封装模型响应函数
def get_response(messages):
    response = dashscope.MultiModalConversation.call(
        model='qwen-vl-plus',
        messages=messages
    )
    return response

content = [
    {'image': 'https://aiwucai.oss-cn-huhehaote.aliyuncs.com/pdf_table.jpg'}, # Either a local path or an url
    {'text': '这是一个表格图片，帮我提取里面的内容，输出JSON格式'}
]

messages=[{"role": "user", "content": content}]
# 得到响应
response = get_response(messages)
response
# Out:
# MultiModalConversationResponse(status_code=<HTTPStatus.OK: 200>, request_id='7397d2c4-1d08-9026-b195-872cb7e34f63', code='', message='', output=MultiModalConversationOutput(choices=[Choice(finish_reason='stop', message=Message({'role': 'assistant', 'content': [{'text': '根据提供的表格图片，以下是提取的内容并以JSON格式输出：\n\n```json\n{\n  "客户名称": "",\n  "联系方式": "",\n  "产品型号": "",\n  "客户诉求": "",\n  "问题产品追综": "",\n  "客户诉求点": ["退货", "换货", "维修"],\n  "描述人/提报人": "2018年__月__日",\n  "问题要因分析": {\n    "原因归属": ["设计", "可靠性", "品质部", "生产部", "仓储", "运输", "其它"],\n    "零时对策建意": "更换液压头，更换阀盘。",\n    "对策方法": ["库存产品再检验", "退回二级供应商", "生产停产纠正", "其它"]\n  },\n  "改善措施": {\n    "1、防止发生对策": "",\n    "建意人": "2018年__月__日",\n    "要求完成时间": "2018年__月__日",\n    "进程追踪": ["按时完成", "延期完成", "未完成"],\n    "纠正归属": ["设计部", "品质部", "装配车间", "压铸车间", "车床车间", "仓库", "运输", "其它"]\n  },\n  "备注说明": ""\n}\n```\n\n### 说明：\n1. **客户信息**：包括客户名称、联系方式、产品型号和客户诉求。\n2. **问题描述**：详细描述了客户的问题产品追综和客户诉求点（退货、换货、维修）。\n3. **问题分析**：分析了问题的原因归属，并提出了零时对策建议和具体的对策方法。\n4. **改善措施**：列出了防止问题再次发生的对策，并指定了建意人、要求完成时间和进程追踪情况。\n5. **纠正归属**：明确了需要纠正的部门或车间。\n6. **备注说明**：预留了备注说明的字段。\n\n请根据实际填写的内容进一步完善JSON数据。如果有具体的填写内容，可以提供给我，我可以帮助你生成更准确的JSON格式数据。'}], 'reasoning_content': ''}))], audio=None), usage=MultiModalConversationUsage(input_tokens=790, output_tokens=439, characters=0))

# %%
print(response.output.choices[0].message.content[0]['text'])
# Out:
# 根据提供的表格图片，以下是提取的内容并以JSON格式输出：
#
# ```json
# {
#   "客户名称": "",
#   "联系方式": "",
#   "产品型号": "",
#   "客户诉求": "",
#   "问题产品追综": "",
#   "客户诉求点": ["退货", "换货", "维修"],
#   "描述人/提报人": "2018年__月__日",
#   "问题要因分析": {
#     "原因归属": ["设计", "可靠性", "品质部", "生产部", "仓储", "运输", "其它"],
#     "零时对策建意": "更换液压头，更换阀盘。",
#     "对策方法": ["库存产品再检验", "退回二级供应商", "生产停产纠正", "其它"]
#   },
#   "改善措施": {
#     "1、防止发生对策": "",
#     "建意人": "2018年__月__日",
#     "要求完成时间": "2018年__月__日",
#     "进程追踪": ["按时完成", "延期完成", "未完成"],
#     "纠正归属": ["设计部", "品质部", "装配车间", "压铸车间", "车床车间", "仓库", "运输", "其它"]
#   },
#   "备注说明": ""
# }
# ```
#
# ### 说明：
# 1. **客户信息**：包括客户名称、联系方式、产品型号和客户诉求。
# 2. **问题描述**：详细描述了客户的问题产品追综和客户诉求点（退货、换货、维修）。
# 3. **问题分析**：分析了问题的原因归属，并提出了零时对策建议和具体的对策方法。
# 4. **改善措施**：列出了防止问题再次发生的对策，并指定了建意人、要求完成时间和进程追踪情况。
# 5. **纠正归属**：明确了需要纠正的部门或车间。
# 6. **备注说明**：预留了备注说明的字段。
#
# 请根据实际填写的内容进一步完善JSON数据。如果有具体的填写内容，可以提供给我，我可以帮助你生成更准确的JSON格式数据。
